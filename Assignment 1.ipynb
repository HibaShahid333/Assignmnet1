# %% [markdown]
# # Question 1

# %%
import pandas as pd

# %%
df = pd.read_csv("jsrt_metadata.csv")

# %%
df.isnull()
# Out:
#      study_id  subtlety   size    age  gender      x      y  state  position  \
# 0       False     False  False  False   False  False  False  False     False
# 1       False     False  False  False   False  False  False  False     False
# 2       False     False  False  False   False  False  False  False     False
# 3       False     False  False  False   False  False  False  False     False
# 4       False     False  False  False   False  False  False  False     False
# ..        ...       ...    ...    ...     ...    ...    ...    ...       ...
# 242     False      True   True  False   False   True   True  False      True
# 243     False      True   True  False   False   True   True  False      True
# 244     False      True   True  False   False   True   True  False      True
# 245     False      True   True  False   False   True   True  False      True
# 246     False      True   True  False   False   True   True  False      True
#
#      diagnosis
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 242       True
# 243       True
# 244       True
# 245       True
# 246       True
#
# [247 rows x 10 columns]

# %%
df.head(10)
# Out:
#        study_id  subtlety  size age  gender       x       y      state  \
# 0  JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0  malignant
# 1  JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0     benign
# 2  JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0  malignant
# 3  JPCLN004.png       5.0  14.0  68  Female   606.0   836.0     benign
# 4  JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0  malignant
# 5  JPCLN006.png       5.0  14.0  64  Female   660.0   524.0     benign
# 6  JPCLN007.png       5.0  18.0  69    Male   459.0   852.0  malignant
# 7  JPCLN008.png       5.0  10.0  44  Female   508.0   938.0     benign
# 8  JPCLN009.png       5.0  28.0  61  Female  1593.0   930.0  malignant
# 9  JPCLN010.png       5.0  25.0  60  Female   647.0   594.0  malignant
#
#              position           diagnosis
# 0        l.upper lobe         lung cancer
# 1    l.upper lobe(S5)  pulmonary hematoma
# 2  l.upper lobe(S1+2)         lung cancer
# 3        r.upper lobe   Inflammatory mass
# 4    l.upper lobe(S3)         lung cancer
# 5    r.upper lobe(S2)         tuberculoma
# 6    r.upper lobe(S3)         lung cancer
# 7        r.lower lobe           granuloma
# 8    l.lower lobe(S6)         lung cancer
# 9    r.upper lobe(S2)         lung cancer

# %%
import numpy as np

# %%
df.replace(' ',np.nan,inplace=True)

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# 0          l.upper lobe         lung cancer
# 1      l.upper lobe(S5)  pulmonary hematoma
# 2    l.upper lobe(S1+2)         lung cancer
# 3          r.upper lobe   Inflammatory mass
# 4      l.upper lobe(S3)         lung cancer
# ..                  ...                 ...
# 242                 NaN                 NaN
# 243                 NaN                 NaN
# 244                 NaN                 NaN
# 245                 NaN                 NaN
# 246                 NaN                 NaN
#
# [247 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           0
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
df['position'].head(10)
# Out:
# 0          l.upper lobe
# 1      l.upper lobe(S5)
# 2    l.upper lobe(S1+2)
# 3          r.upper lobe
# 4      l.upper lobe(S3)
# 5      r.upper lobe(S2)
# 6      r.upper lobe(S3)
# 7          r.lower lobe
# 8      l.lower lobe(S6)
# 9      r.upper lobe(S2)
# Name: position, dtype: object

# %%
m=df['subtlety'].astype('float').mean()
df['subtlety'].replace(np.nan,m,inplace=True)

# %%
m=df['size'].astype('float').mean()
df['size'].replace(np.nan,m,inplace=True)
m=df['x'].astype('float').mean()
df['x'].replace(np.nan,m,inplace=True)

# %%
mx=df['y'].astype('float').mean()
df['y'].replace(np.nan,mx,inplace=True)

# %%
mx=df['diagnosis'].value_counts().idxmax()
df['diagnosis'].replace(np.nan,mx,inplace=True)

# %%
mx=df['position'].value_counts().idxmax()
df['position'].replace(np.nan,mx,inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
plt.pyplot.title('Programming for big data')
plt.pyplot.xlabel('Disease')
plt.pyplot.ylabel('Patients')
plt.pyplot.hist(df['diagnosis'].value_counts(),ec='red')
# Out:
# (array([30.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  15.8,  30.6,  45.4,  60.2,  75. ,  89.8, 104.6, 119.4,
#         134.2, 149. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Question 2

# %%
plt.pyplot.pie(df[['diagnosis', 'state']].value_counts(), shadow=True, autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1b4a31b5670>,
#   <matplotlib.patches.Wedge at 0x1b4a31c50d0>,
#   <matplotlib.patches.Wedge at 0x1b4a31c5a60>,
#   <matplotlib.patches.Wedge at 0x1b4a31d2430>,
#   <matplotlib.patches.Wedge at 0x1b4a31d2dc0>,
#   <matplotlib.patches.Wedge at 0x1b4a31e0790>,
#   <matplotlib.patches.Wedge at 0x1b4a31ee160>,
#   <matplotlib.patches.Wedge at 0x1b4a31eeaf0>,
#   <matplotlib.patches.Wedge at 0x1b4a31fb4c0>,
#   <matplotlib.patches.Wedge at 0x1b4a31fbe50>,
#   <matplotlib.patches.Wedge at 0x1b4a318f3a0>,
#   <matplotlib.patches.Wedge at 0x1b4a32181c0>,
#   <matplotlib.patches.Wedge at 0x1b4a3218b50>,
#   <matplotlib.patches.Wedge at 0x1b4a3223520>,
#   <matplotlib.patches.Wedge at 0x1b4a3223eb0>,
#   <matplotlib.patches.Wedge at 0x1b4a3232880>,
#   <matplotlib.patches.Wedge at 0x1b4a3241250>,
#   <matplotlib.patches.Wedge at 0x1b4a3241be0>,
#   <matplotlib.patches.Wedge at 0x1b4a324f5b0>,
#   <matplotlib.patches.Wedge at 0x1b4a324ff40>,
#   <matplotlib.patches.Wedge at 0x1b4a325e910>,
#   <matplotlib.patches.Wedge at 0x1b4a32462e0>,
#   <matplotlib.patches.Wedge at 0x1b4a3246c70>,
#   <matplotlib.patches.Wedge at 0x1b4a3277640>,
#   <matplotlib.patches.Wedge at 0x1b4a3277e20>,
#   <matplotlib.patches.Wedge at 0x1b4a32847f0>,
#   <matplotlib.patches.Wedge at 0x1b4a32931c0>,
#   <matplotlib.patches.Wedge at 0x1b4a3293b50>,
#   <matplotlib.patches.Wedge at 0x1b4a32a1520>,
#   <matplotlib.patches.Wedge at 0x1b4a32a1eb0>,
#   <matplotlib.patches.Wedge at 0x1b4a32ae880>,
#   <matplotlib.patches.Wedge at 0x1b4a32bc250>,
#   <matplotlib.patches.Wedge at 0x1b4a32bcbe0>],
#  [Text(0.4160997880601955, 1.0182637017866543, ''),
#   Text(-1.0977763719436746, 0.0699073472689613, ''),
#   Text(-0.6476951466668902, -0.8890956062112532, ''),
#   Text(-0.1741504033155111, -1.0861268972937945, ''),
#   Text(0.1325903404163534, -1.091979762462783, ''),
#   Text(0.3372563642798493, -1.0470234690553684, ''),
#   Text(0.4799714817413008, -0.9897612725880217, ''),
#   Text(0.5780254272429179, -0.9358881372582102, ''),
#   Text(0.6700999667671853, -0.8723336715607264, ''),
#   Text(0.7450097309069345, -0.8092962997901184, ''),
#   Text(0.7949362176160618, -0.7603133629775749, ''),
#   Text(0.8325726606439009, -0.7189038633561069, ''),
#   Text(0.8680545649138726, -0.6756339780770263, ''),
#   Text(0.901290110046126, -0.6306156813250381, ''),
#   Text(0.9321932888084875, -0.5839654718392313, ''),
#   Text(0.9606841296867188, -0.5358040714366326, ''),
#   Text(0.9866889038354972, -0.4862561126072403, ''),
#   Text(1.010140315874562, -0.435449815988984, ''),
#   Text(1.0260164705727877, -0.39659828808677444, ''),
#   Text(1.0357721034648881, -0.37037298724923423, ''),
#   Text(1.0448575329321228, -0.34390803403671427, ''),
#   Text(1.053266880185205, -0.31722055277822914, ''),
#   Text(1.0609947038984693, -0.29032781179108497, ''),
#   Text(1.068036003730719, -0.26324721220730035, ''),
#   Text(1.0743862235607313, -0.23599627671408402, ''),
#   Text(1.0800412544353253, -0.20859263821566004, ''),
#   Text(1.0849974372280897, -0.18105402842377658, ''),
#   Text(1.0892515650070453, -0.15339826638428047, ''),
#   Text(1.0928008851097117, -0.12564324694718182, ''),
#   Text(1.0956431009242373, -0.09780692918766887, ''),
#   Text(1.0977763733754364, -0.06990732478556444, ''),
#   Text(1.0991993221147769, -0.041962486370749334, ''),
#   Text(1.0999110264135428, -0.013990495842078806, '')],
#  [Text(0.2269635207601066, 0.5554165646109023, '37.7%'),
#   Text(-0.598787111969277, 0.03813128032852434, '22.7%'),
#   Text(-0.35328826181830375, -0.48496123975159255, '9.3%'),
#   Text(-0.09499112908118786, -0.5924328530693425, '5.7%'),
#   Text(0.07232200386346549, -0.5956253249796997, '3.2%'),
#   Text(0.18395801687991778, -0.5711037103938372, '2.8%'),
#   Text(0.2618026264043458, -0.5398697850480118, '1.6%'),
#   Text(0.31528659667795517, -0.5104844385044782, '1.6%'),
#   Text(0.36550907278210104, -0.4758183663058507, '1.6%'),
#   Text(0.4063689441310551, -0.4414343453400646, '1.2%'),
#   Text(0.43360157324512455, -0.4147163798059499, '0.8%'),
#   Text(0.4541305421694004, -0.39212938001242187, '0.8%'),
#   Text(0.47348430813483955, -0.3685276244056507, '0.8%'),
#   Text(0.4916127872978869, -0.34397218981365707, '0.8%'),
#   Text(0.5084690666228113, -0.31852662100321705, '0.8%'),
#   Text(0.5240095252836647, -0.29225676623816316, '0.8%'),
#   Text(0.5381939475466347, -0.2652306068766765, '0.8%'),
#   Text(0.5509856268406702, -0.2375180814485367, '0.8%'),
#   Text(0.5596453475851568, -0.2163263389564224, '0.4%'),
#   Text(0.5649666018899389, -0.2020216294086732, '0.4%'),
#   Text(0.5699222906902488, -0.18758620038366233, '0.4%'),
#   Text(0.5745092073737481, -0.1730293924244886, '0.4%'),
#   Text(0.5787243839446196, -0.15836062461331904, '0.4%'),
#   Text(0.5825650929440286, -0.14358938847670927, '0.4%'),
#   Text(0.5860288492149442, -0.12872524184404582, '0.4%'),
#   Text(0.5891134115101774, -0.11377780266308728, '0.4%'),
#   Text(0.5918167839425943, -0.09875674277660539, '0.4%'),
#   Text(0.5941372172765701, -0.08367178166415297, '0.4%'),
#   Text(0.5960732100598427, -0.06853268015300826, '0.4%'),
#   Text(0.5976235095950385, -0.05334923410236483, '0.4%'),
#   Text(0.598787112750238, -0.03813126806485333, '0.4%'),
#   Text(0.59956326660806, -0.022888628929499635, '0.4%'),
#   Text(0.5999514689528415, -0.0076311795502248024, '0.4%')])

# %% [markdown]
# # Question3

# %%
plt.pyplot.pie(df[['diagnosis', 'gender']].value_counts(), shadow=True, autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1b4a3307dc0>,
#   <matplotlib.patches.Wedge at 0x1b4a3314820>,
#   <matplotlib.patches.Wedge at 0x1b4a33221f0>,
#   <matplotlib.patches.Wedge at 0x1b4a3322b80>,
#   <matplotlib.patches.Wedge at 0x1b4a332e550>,
#   <matplotlib.patches.Wedge at 0x1b4a332eee0>,
#   <matplotlib.patches.Wedge at 0x1b4a333b8e0>,
#   <matplotlib.patches.Wedge at 0x1b4a334a2b0>,
#   <matplotlib.patches.Wedge at 0x1b4a334ac40>,
#   <matplotlib.patches.Wedge at 0x1b4a3358610>,
#   <matplotlib.patches.Wedge at 0x1b4a32dc970>,
#   <matplotlib.patches.Wedge at 0x1b4a3368940>,
#   <matplotlib.patches.Wedge at 0x1b4a3374310>,
#   <matplotlib.patches.Wedge at 0x1b4a3374ca0>,
#   <matplotlib.patches.Wedge at 0x1b4a3381670>,
#   <matplotlib.patches.Wedge at 0x1b4a3381fd0>,
#   <matplotlib.patches.Wedge at 0x1b4a33909d0>,
#   <matplotlib.patches.Wedge at 0x1b4a339d3a0>,
#   <matplotlib.patches.Wedge at 0x1b4a339dd30>,
#   <matplotlib.patches.Wedge at 0x1b4a33ab700>,
#   <matplotlib.patches.Wedge at 0x1b4a33b90d0>,
#   <matplotlib.patches.Wedge at 0x1b4a33b9a60>,
#   <matplotlib.patches.Wedge at 0x1b4a33c6430>,
#   <matplotlib.patches.Wedge at 0x1b4a33c6dc0>,
#   <matplotlib.patches.Wedge at 0x1b4a33d3550>,
#   <matplotlib.patches.Wedge at 0x1b4a33d3ee0>,
#   <matplotlib.patches.Wedge at 0x1b4a33e48b0>,
#   <matplotlib.patches.Wedge at 0x1b4a33f02b0>,
#   <matplotlib.patches.Wedge at 0x1b4a33f0c40>,
#   <matplotlib.patches.Wedge at 0x1b4a33fe610>,
#   <matplotlib.patches.Wedge at 0x1b4a33fefa0>,
#   <matplotlib.patches.Wedge at 0x1b4a340c970>,
#   <matplotlib.patches.Wedge at 0x1b4a3419340>,
#   <matplotlib.patches.Wedge at 0x1b4a3419cd0>,
#   <matplotlib.patches.Wedge at 0x1b4a34296a0>,
#   <matplotlib.patches.Wedge at 0x1b4a3429fd0>,
#   <matplotlib.patches.Wedge at 0x1b4a3436a00>,
#   <matplotlib.patches.Wedge at 0x1b4a34443d0>,
#   <matplotlib.patches.Wedge at 0x1b4a3444d60>,
#   <matplotlib.patches.Wedge at 0x1b4a3451730>,
#   <matplotlib.patches.Wedge at 0x1b4a345e100>,
#   <matplotlib.patches.Wedge at 0x1b4a345ea90>],
#  [Text(0.6363346275672915, 0.8972615236143789, ''),
#   Text(-1.0532668978197752, 0.3172204942261888, ''),
#   Text(-0.7346562374226806, -0.8187064265143827, ''),
#   Text(-0.4546412912955383, -1.0016492880490286, ''),
#   Text(-0.22915892112618208, -1.0758653209711169, ''),
#   Text(-0.03497125507116722, -1.0994439555151265, ''),
#   Text(0.1186912064393753, -1.0935777967360008, ''),
#   Text(0.24282413163038521, -1.0728636637979447, ''),
#   Text(0.35054591715721556, -1.0426492986447584, ''),
#   Text(0.4418650615883634, -1.0073506178821314, ''),
#   Text(0.5173793659026957, -0.9707309574429595, ''),
#   Text(0.5898820050620465, -0.9284606723518126, ''),
#   Text(0.6476952299100254, -0.8890955455696534, ''),
#   Text(0.6920712843575617, -0.8550072148044573, ''),
#   Text(0.7346563907283228, -0.8187062889474065, ''),
#   Text(0.7753403469144082, -0.780286707849522, ''),
#   Text(0.8140178706208652, -0.739847894036249, ''),
#   Text(0.8505888718161299, -0.6974944954209773, ''),
#   Text(0.8849587117458758, -0.6533361144962676, ''),
#   Text(0.917038447840006, -0.6074870247035674, ''),
#   Text(0.9395452008568503, -0.5720618983526704, ''),
#   Text(0.953791771239662, -0.5479792488000879, ''),
#   Text(0.9674211841323701, -0.5235420255260537, ''),
#   Text(0.9804246205301289, -0.49876604080305315, ''),
#   Text(0.9927936664704659, -0.47366732610148415, ''),
#   Text(1.0045203184775933, -0.44826212171638424, ''),
#   Text(1.0155969887411123, -0.4225668662590398, ''),
#   Text(1.0260165100257577, -0.3965981860202648, ''),
#   Text(1.0357721403090063, -0.3703728842122498, ''),
#   Text(1.0448575671435487, -0.34390793009592663, ''),
#   Text(1.053266911741802, -0.31722044800089294, ''),
#   Text(1.0609947327798186, -0.2903277062449971, ''),
#   Text(1.068036029918133, -0.2632471059607552, ''),
#   Text(1.074386247037265, -0.23599616983582916, ''),
#   Text(1.080041275185788, -0.2085925307748517, ''),
#   Text(1.0849974552390549, -0.18105392048993413, ''),
#   Text(1.0892515802668588, -0.1533981580272442, ''),
#   Text(1.0928008976084993, -0.1256431382370649, ''),
#   Text(1.0956431106539117, -0.09780682019481292, ''),
#   Text(1.0977763803297018, -0.06990721558049502, ''),
#   Text(1.0991993262891335, -0.04196237702412735, ''),
#   Text(1.0999110278052897, -0.013990386424657735, '')],
#  [Text(0.34709161503670444, 0.4894153765169339, '30.4%'),
#   Text(-0.5745092169926046, 0.17302936048701206, '30.0%'),
#   Text(-0.4007215840487348, -0.4465671417351178, '6.1%'),
#   Text(-0.24798615888847542, -0.5463541571176519, '3.6%'),
#   Text(-0.12499577515973567, -0.5868356296206092, '3.2%'),
#   Text(-0.019075230038818478, -0.5996967030082508, '2.4%'),
#   Text(0.06474065805784106, -0.5964969800378185, '2.0%'),
#   Text(0.13244952634384646, -0.5851983620716061, '1.6%'),
#   Text(0.19120686390393574, -0.5687177992607773, '1.6%'),
#   Text(0.24101730632092547, -0.5494639733902534, '1.2%'),
#   Text(0.2822069268560158, -0.5294896131507051, '1.2%'),
#   Text(0.32175382094293437, -0.5064330940100795, '1.2%'),
#   Text(0.3532883072236502, -0.4849612066743564, '0.8%'),
#   Text(0.3774934278313972, -0.4663675717115221, '0.8%'),
#   Text(0.4007216676699942, -0.4465670666985853, '0.8%'),
#   Text(0.42291291649876805, -0.4256109315542847, '0.8%'),
#   Text(0.44400974761138096, -0.4035533967470448, '0.8%'),
#   Text(0.4639575664451617, -0.38045154295689665, '0.8%'),
#   Text(0.4827047518613867, -0.3563651533616005, '0.8%'),
#   Text(0.5002027897309124, -0.33135655892921856, '0.8%'),
#   Text(0.5124792004673728, -0.3120337627378202, '0.4%'),
#   Text(0.5202500570398155, -0.2988977720727751, '0.4%'),
#   Text(0.52768428225402, -0.2855683775596656, '0.4%'),
#   Text(0.5347770657437066, -0.27205420407439257, '0.4%'),
#   Text(0.5415238180747994, -0.258363996055355, '0.4%'),
#   Text(0.5479201737150509, -0.24450661184530048, '0.4%'),
#   Text(0.5539619938587884, -0.23049101795947619, '0.4%'),
#   Text(0.5596453691049587, -0.21632628328378078, '0.4%'),
#   Text(0.5649666219867306, -0.20202157320668168, '0.4%'),
#   Text(0.5699223093510265, -0.18758614368868723, '0.4%'),
#   Text(0.5745092245864374, -0.17302933527321432, '0.4%'),
#   Text(0.5787243996980829, -0.1583605670427257, '0.4%'),
#   Text(0.5825651072280725, -0.14358933052404826, '0.4%'),
#   Text(0.5860288620203262, -0.1287251835468159, '0.4%'),
#   Text(0.5891134228286116, -0.11377774405901, '0.4%'),
#   Text(0.5918167937667571, -0.09875668390360041, '0.4%'),
#   Text(0.5941372256001046, -0.083671722560315, '0.4%'),
#   Text(0.5960732168773633, -0.06853262085658085, '0.4%'),
#   Text(0.5976235149021336, -0.05334917465171613, '0.4%'),
#   Text(0.5987871165434737, -0.03813120849845182, '0.4%'),
#   Text(0.5995632688849819, -0.022888569285887644, '0.4%'),
#   Text(0.5999514697119762, -0.007631119867995128, '0.4%')])
